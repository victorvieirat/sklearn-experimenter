# %% [markdown]
# # Creating Examples as datasets

# %%
# !mkdir bases
# Out:
# mkdir: cannot create directory ‘bases’: File exists

# %%
from sklearn.datasets import make_blobs
import pandas as pd
for i in range(2):
    i+=1
    X, y = make_blobs(n_samples=1000, centers=5, n_features=3,cluster_std=2)
    X = pd.DataFrame(X)
    
    # Define the mapping of values to replacements
    replacement_mapping = {
        0: 'A',
        1: 'B',
        2: 'C',
        3: 'D',
        4: 'E'
    }

    # Replace values in the list
    y = [replacement_mapping.get(value, value) for value in y]
    X['string'] = [replacement_mapping[i%3] for i in range(len(X))]
    X['class'] = y
    X.to_csv(f'bases/df{i}.csv',index=False,decimal=',',sep=';')

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from experimenter import ModelRunner

# %% [markdown]
# # Configurando

# %%
runner = ModelRunner()


def custom_reader(filename):
    data = pd.read_csv(filename,decimal=',',sep=';')
    return data


#Função personalizada para leitura do dataset
runner.data.reader = custom_reader

#Bases

runner.data.add_datasets(['bases/', #Path to folder
                          'bases/df1.csv', #Path to file
                          (X,'X'), #Dataframe with name
                          X #Dataframe without name
                          ])

#Splits
runner.splits.add_holdout([.3]) #Holdouts
runner.splits.add_fold([3]) #Kfolds

pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Apply standard normalization
    ('bagging',  BaggingClassifier(estimator=knn()))
])

#Modelos
runner.models.add_models(['DecisionTreeClassifier', 
                         BaggingClassifier(estimator=knn()),
                         pipeline]
                         )

#Métricas
runner.metrics.add_score(['matrix',
                          'acc',
                          'f1_macro'] #Equivalente a  f1_score(y_true, y_pred, average='micro'), f1_score só funciona para binários
                          )

#Seeds
runner.random.add_model_seed([42])
#runner.random.add_model_seed([42,43])
#runner.random.add_split_seed([10,12])

runner.summarize()

runner.save_path ='output.pkl'
# Out:
# Number of dataframes: 5
# Metrics used: confusion_matrix, accuracy_score, f1_score
# Split method:
#      - Holdouts: [0.3]
#      - Folds: [3]
# Seeds methods:
#      - Each model will run 1 times witch seeds: [42]
#      - Each split will run 1 times witch seeds: [42]
# Models used: DecisionTreeClassifier, BaggingClassifier, Pipeline

# %%
#Acessando um dataset
runner.data.datasets[-1].get_feature()
# Out:
#             0         1          2  string_A  string_B  string_C
# 0    6.419566  3.608102  -2.575205         1         0         0
# 1    9.102536  4.767435   0.154750         0         1         0
# 2    8.295302  1.728823  -2.656761         0         0         1
# 3   -2.090848 -5.671698   8.577922         1         0         0
# 4    9.129001  8.540071  -1.147410         0         1         0
# ..        ...       ...        ...       ...       ...       ...
# 995 -2.603826 -6.909704   8.084810         0         0         1
# 996 -5.999522  7.049011  10.858013         1         0         0
# 997  4.682709  6.851010  -7.465668         0         1         0
# 998 -8.988807 -2.804796   0.008418         0         0         1
# 999 -6.483172 -1.432902  -0.845308         1         0         0
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Executando

# %% [markdown]
# Para os dados não serem perdidos ao acontecer um erro save_each_evaluation salva atualiza o arquivo result.pkl a cada execução.

# %%
runner.run(save_each_evaluation=True)

# %%
pd.DataFrame(runner.results)
# Out:
#           df_name              model_name  \
# 0   bases/df1.csv  DecisionTreeClassifier
# 1   bases/df1.csv  DecisionTreeClassifier
# 2   bases/df1.csv  DecisionTreeClassifier
# 3   bases/df1.csv  DecisionTreeClassifier
# 4   bases/df1.csv       BaggingClassifier
# 5   bases/df1.csv       BaggingClassifier
# 6   bases/df1.csv       BaggingClassifier
# 7   bases/df1.csv       BaggingClassifier
# 8   bases/df1.csv                Pipeline
# 9   bases/df1.csv                Pipeline
# 10  bases/df1.csv                Pipeline
# 11  bases/df1.csv                Pipeline
# 12  bases/df2.csv  DecisionTreeClassifier
# 13  bases/df2.csv  DecisionTreeClassifier
# 14  bases/df2.csv  DecisionTreeClassifier
# 15  bases/df2.csv  DecisionTreeClassifier
# 16  bases/df2.csv       BaggingClassifier
# 17  bases/df2.csv       BaggingClassifier
# 18  bases/df2.csv       BaggingClassifier
# 19  bases/df2.csv       BaggingClassifier
# 20  bases/df2.csv                Pipeline
# 21  bases/df2.csv                Pipeline
# 22  bases/df2.csv                Pipeline
# 23  bases/df2.csv                Pipeline
# 24  bases/df1.csv  DecisionTreeClassifier
# 25  bases/df1.csv  DecisionTreeClassifier
# 26  bases/df1.csv  DecisionTreeClassifier
# 27  bases/df1.csv  DecisionTreeClassifier
# 28  bases/df1.csv       BaggingClassifier
# 29  bases/df1.csv       BaggingClassifier
# 30  bases/df1.csv       BaggingClassifier
# 31  bases/df1.csv       BaggingClassifier
# 32  bases/df1.csv                Pipeline
# 33  bases/df1.csv                Pipeline
# 34  bases/df1.csv                Pipeline
# 35  bases/df1.csv                Pipeline
# 36              X  DecisionTreeClassifier
# 37              X  DecisionTreeClassifier
# 38              X  DecisionTreeClassifier
# 39              X  DecisionTreeClassifier
# 40              X       BaggingClassifier
# 41              X       BaggingClassifier
# 42              X       BaggingClassifier
# 43              X       BaggingClassifier
# 44              X                Pipeline
# 45              X                Pipeline
# 46              X                Pipeline
# 47              X                Pipeline
# 48       Dataset0  DecisionTreeClassifier
# 49       Dataset0  DecisionTreeClassifier
# 50       Dataset0  DecisionTreeClassifier
# 51       Dataset0  DecisionTreeClassifier
# 52       Dataset0       BaggingClassifier
# 53       Dataset0       BaggingClassifier
# 54       Dataset0       BaggingClassifier
# 55       Dataset0       BaggingClassifier
# 56       Dataset0                Pipeline
# 57       Dataset0                Pipeline
# 58       Dataset0                Pipeline
# 59       Dataset0                Pipeline
#
#                                          model_params split_type  split_value  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 4   {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 5   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 6   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 7   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 8   {'memory': None, 'steps': [('scaler', Standard...    holdout          0.3
# 9   {'memory': None, 'steps': [('scaler', Standard...   fold_1/3          3.0
# 10  {'memory': None, 'steps': [('scaler', Standard...   fold_2/3          3.0
# 11  {'memory': None, 'steps': [('scaler', Standard...   fold_3/3          3.0
# 12  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 13  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 14  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 15  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 16  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 17  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 18  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 19  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 20  {'memory': None, 'steps': [('scaler', Standard...    holdout          0.3
# 21  {'memory': None, 'steps': [('scaler', Standard...   fold_1/3          3.0
# 22  {'memory': None, 'steps': [('scaler', Standard...   fold_2/3          3.0
# 23  {'memory': None, 'steps': [('scaler', Standard...   fold_3/3          3.0
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 25  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 26  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 27  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 28  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 29  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 30  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 31  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 32  {'memory': None, 'steps': [('scaler', Standard...    holdout          0.3
# 33  {'memory': None, 'steps': [('scaler', Standard...   fold_1/3          3.0
# 34  {'memory': None, 'steps': [('scaler', Standard...   fold_2/3          3.0
# 35  {'memory': None, 'steps': [('scaler', Standard...   fold_3/3          3.0
# 36  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 37  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 38  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 39  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 40  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 41  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 42  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 43  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 44  {'memory': None, 'steps': [('scaler', Standard...    holdout          0.3
# 45  {'memory': None, 'steps': [('scaler', Standard...   fold_1/3          3.0
# 46  {'memory': None, 'steps': [('scaler', Standard...   fold_2/3          3.0
# 47  {'memory': None, 'steps': [('scaler', Standard...   fold_3/3          3.0
# 48  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 49  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 50  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 51  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 52  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 53  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 54  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 55  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 56  {'memory': None, 'steps': [('scaler', Standard...    holdout          0.3
# 57  {'memory': None, 'steps': [('scaler', Standard...   fold_1/3          3.0
# 58  {'memory': None, 'steps': [('scaler', Standard...   fold_2/3          3.0
# 59  {'memory': None, 'steps': [('scaler', Standard...   fold_3/3          3.0
#
#     model_seed  split_seed                                   confusion_matrix  \
# 0         42.0          42  [[61, 6, 0, 0, 0], [2, 58, 0, 0, 0], [0, 0, 38...
# 1         42.0          42  [[66, 11, 0, 0, 0], [2, 60, 0, 0, 0], [0, 0, 4...
# 2         42.0          42  [[54, 1, 0, 0, 0], [7, 63, 0, 1, 0], [0, 0, 38...
# 17        0.958084  0.956293
# 18        0.960961  0.961836
# 19        0.963964  0.964208
# 20        0.966667  0.965028
# 21        0.964072  0.962426
# 22        0.957958  0.958605
# 23        0.975976  0.976046
# 24        0.696667  0.683968
# 25        0.682635  0.675196
# 26        0.693694  0.703183
# 27        0.732733  0.730356
# 28        0.736667  0.727318
# 29        0.745509  0.741444
# 30        0.729730  0.737694
# 31        0.762763  0.757873
# 32        0.746667  0.738006
# 33        0.760479  0.755851
# 34        0.702703  0.709455
# 35        0.756757  0.752409
# 36        0.956667  0.955396
# 37        0.955090  0.953050
# 38        0.933934  0.933236
# 39        0.948949  0.948430
# 40        0.963333  0.961960
# 41        0.958084  0.956293
# 42        0.960961  0.961836
# 43        0.963964  0.964208
# 44        0.960000  0.958641
# 45        0.961078  0.959121
# 46        0.957958  0.958605
# 47        0.972973  0.973172
# 48        0.956667  0.955396
# 49        0.955090  0.953050
# 50        0.933934  0.933236
# 51        0.948949  0.948430
# 52        0.963333  0.961960
# 53        0.958084  0.956293
# 54        0.960961  0.961836
# 55        0.963964  0.964208
# 56        0.970000  0.968634
# 57        0.967066  0.965517
# 58        0.957958  0.958544
# 59        0.975976  0.976046

# %%
pd.read_pickle("result.pkl")
# Out:
#           df_name              model_name  \
# 0   bases/df1.csv  DecisionTreeClassifier
# 1   bases/df1.csv  DecisionTreeClassifier
# 2   bases/df1.csv  DecisionTreeClassifier
# 3   bases/df1.csv  DecisionTreeClassifier
# 4   bases/df1.csv       BaggingClassifier
# 5   bases/df1.csv       BaggingClassifier
# 6   bases/df1.csv       BaggingClassifier
# 7   bases/df1.csv       BaggingClassifier
# 8   bases/df2.csv  DecisionTreeClassifier
# 9   bases/df2.csv  DecisionTreeClassifier
# 10  bases/df2.csv  DecisionTreeClassifier
# 11  bases/df2.csv  DecisionTreeClassifier
# 12  bases/df2.csv       BaggingClassifier
# 13  bases/df2.csv       BaggingClassifier
# 14  bases/df2.csv       BaggingClassifier
# 15  bases/df2.csv       BaggingClassifier
# 16  bases/df1.csv  DecisionTreeClassifier
# 17  bases/df1.csv  DecisionTreeClassifier
# 18  bases/df1.csv  DecisionTreeClassifier
# 19  bases/df1.csv  DecisionTreeClassifier
# 20  bases/df1.csv       BaggingClassifier
# 21  bases/df1.csv       BaggingClassifier
# 22  bases/df1.csv       BaggingClassifier
# 23  bases/df1.csv       BaggingClassifier
# 24              X  DecisionTreeClassifier
# 25              X  DecisionTreeClassifier
# 26              X  DecisionTreeClassifier
# 27              X  DecisionTreeClassifier
# 28              X       BaggingClassifier
# 29              X       BaggingClassifier
# 30              X       BaggingClassifier
# 31              X       BaggingClassifier
# 32       Dataset0  DecisionTreeClassifier
# 33       Dataset0  DecisionTreeClassifier
# 34       Dataset0  DecisionTreeClassifier
# 35       Dataset0  DecisionTreeClassifier
# 36       Dataset0       BaggingClassifier
# 37       Dataset0       BaggingClassifier
# 38       Dataset0       BaggingClassifier
# 39       Dataset0       BaggingClassifier
#
#                                          model_params split_type  split_value  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 4   {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 5   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 6   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 7   {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 8   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 9   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 10  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 11  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 12  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 13  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 14  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 15  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 16  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 17  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 18  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 19  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 20  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 21  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 22  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 23  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 25  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 26  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 27  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 28  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 29  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 30  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 31  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 33  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_1/3          3.0
# 34  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_2/3          3.0
# 35  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...   fold_3/3          3.0
# 36  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 37  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_1/3          3.0
# 38  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_2/3          3.0
# 39  {'base_estimator': 'deprecated', 'bootstrap': ...   fold_3/3          3.0
#
#     model_seed  split_seed                         confusion_matrix  \
# 0           42          42    [[103, 0, 0], [0, 99, 0], [0, 0, 98]]
# 1           42          42  [[110, 0, 0], [0, 110, 1], [0, 0, 113]]
# 2           42          42  [[118, 0, 0], [0, 113, 0], [0, 0, 102]]
# 3           42          42  [[106, 0, 0], [0, 109, 0], [0, 1, 117]]
# 4           42          42    [[103, 0, 0], [0, 99, 0], [0, 0, 98]]
# 5           42          42  [[110, 0, 0], [0, 110, 0], [0, 0, 114]]
# 6           42          42  [[118, 0, 0], [0, 113, 0], [0, 0, 102]]
# 7           42          42  [[106, 0, 0], [0, 110, 0], [0, 0, 117]]
# 8           42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 9           42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 10          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 11          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
# 12          42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 13          42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 14          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 15          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
# 16          42          42    [[103, 0, 0], [0, 99, 0], [0, 0, 98]]
# 17          42          42  [[110, 0, 0], [0, 110, 1], [0, 0, 113]]
# 18          42          42  [[118, 0, 0], [0, 113, 0], [0, 0, 102]]
# 19          42          42  [[106, 0, 0], [0, 109, 0], [0, 1, 117]]
# 20          42          42    [[103, 0, 0], [0, 99, 0], [0, 0, 98]]
# 21          42          42  [[110, 0, 0], [0, 110, 0], [0, 0, 114]]
# 22          42          42  [[118, 0, 0], [0, 113, 0], [0, 0, 102]]
# 23          42          42  [[106, 0, 0], [0, 110, 0], [0, 0, 117]]
# 24          42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 25          42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 26          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 27          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
# 28          42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 29          42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 30          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 31          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
# 32          42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 33          42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 34          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 35          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
# 36          42          42   [[94, 0, 0], [0, 105, 0], [0, 0, 101]]
# 37          42          42  [[112, 0, 0], [0, 113, 0], [0, 0, 109]]
# 38          42          42  [[117, 0, 0], [0, 112, 0], [0, 0, 104]]
# 39          42          42  [[105, 0, 0], [0, 108, 0], [0, 0, 120]]
#
#     accuracy_score  f1_score
# 0         1.000000  1.000000
# 1         0.997006  0.997006
# 2         1.000000  1.000000
# 3         0.996997  0.996997
# 4         1.000000  1.000000
# 5         1.000000  1.000000
# 6         1.000000  1.000000
# 7         1.000000  1.000000
# 8         1.000000  1.000000
# 9         1.000000  1.000000
# 10        1.000000  1.000000
# 11        1.000000  1.000000
# 12        1.000000  1.000000
# 13        1.000000  1.000000
# 14        1.000000  1.000000
# 15        1.000000  1.000000
# 16        1.000000  1.000000
# 17        0.997006  0.997006
# 18        1.000000  1.000000
# 19        0.996997  0.996997
# 20        1.000000  1.000000
# 21        1.000000  1.000000
# 22        1.000000  1.000000
# 23        1.000000  1.000000
# 24        1.000000  1.000000
# 25        1.000000  1.000000
# 26        1.000000  1.000000
# 27        1.000000  1.000000
# 28        1.000000  1.000000
# 29        1.000000  1.000000
# 30        1.000000  1.000000
# 31        1.000000  1.000000
# 32        1.000000  1.000000
# 33        1.000000  1.000000
# 34        1.000000  1.000000
# 35        1.000000  1.000000
# 36        1.000000  1.000000
# 37        1.000000  1.000000
# 38        1.000000  1.000000
# 39        1.000000  1.000000
