# %%
# !mkdir bases
# Out:
# mkdir: cannot create directory ‘bases’: File exists

# %%
from sklearn.datasets import make_blobs
import pandas as pd
for i in range(5):
    X, y = make_blobs(n_samples=1000, centers=3, n_features=5)
    X = pd.DataFrame(X)
    
    # Define the mapping of values to replacements
    replacement_mapping = {
        0: 'A',
        1: 'B',
        2: 'C'
    }

    # Replace values in the list
    y = [replacement_mapping.get(value, value) for value in y]
    X['string'] = [replacement_mapping[i%3] for i in range(len(X))]
    X['class'] = y
    X.to_csv(f'bases/df{i}.csv',index=False)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier as knn
from experimenter import ModelRunner

# %% [markdown]
# #Configurando

# %%
runner = ModelRunner()

#Bases
runner.data.add_datasets('bases/')

#Splits
#runner.splits.add_holdout([.3,.25])
#runner.splits.add_fold([5,6])
runner.splits.add_holdout([.3])

#Modelos
runner.models.add_models(['DecisionTreeClassifier',
                         'KNeighborsClassifier',
                         'MLPClassifier',
                         'GaussianNB',
                         'LinearSVC',
                         'AdaBoostClassifier',
                         'RandomForestClassifier',
                         BaggingClassifier(estimator=knn())]
                         )

#Métricas
runner.metrics.add_score(['matrix',
                          'acc',
                          'f1_micro'] #Equivalente a  f1_score(y_true, y_pred, average='micro'), f1_score só funciona para binários
                          )

#Seeds
runner.random.add_model_seed([42])
#runner.random.add_model_seed([42,43])
#runner.random.add_split_seed([10,12])

runner.summarize()
# Out:
# Number of dataframes: 5
# Metrics used: confusion_matrix, accuracy_score, f1_score
# Split method:
#      - Holdouts: [0.3]
#      - Folds: []
# Seeds methods:
#      - Each model will run 1 times witch seeds: [42]
#      - Each split will run 1 times witch seeds: [42]
# Models used: DecisionTreeClassifier, KNeighborsClassifier, MLPClassifier, GaussianNB, LinearSVC, AdaBoostClassifier, RandomForestClassifier, BaggingClassifier

# %%
#Acessando um dataset
runner.data.datasets[0].get_feature()
# Out:
#             0         1         2          3         4  string_A  string_B  \
# 0   -3.216186 -6.533007 -0.504173  -6.505495 -6.852330         1         0
# 1    3.819535  5.977496 -7.951837  11.867272 -5.276770         0         1
# 2    5.507398  5.571087 -8.627451   8.512876 -5.923708         0         0
# 3   -5.066012 -8.951776 -1.383665  -5.351642 -5.767104         1         0
# 4    4.504639  8.411392 -9.016082   8.869126 -5.024287         0         1
# ..        ...       ...       ...        ...       ...       ...       ...
# 995  3.895628  5.822019 -7.686460   8.567065 -5.779656         0         0
# 996 -2.944076 -9.331910 -1.793209  -4.696132 -6.429858         1         0
# 997 -6.689051 -7.076758 -2.768790  -5.178994 -5.815830         0         1
# 998 -1.706349 -6.917919 -1.264783  -5.767875 -6.323086         0         0
# 999  2.416612  3.566252 -8.909469   9.056900 -7.347566         1         0
#
#      string_C
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# ..        ...
# 995         1
# 996         0
# 997         0
# 998         1
# 999         0
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Executando

# %% [markdown]
# Para os dados não serem perdidos ao acontecer um erro save_each_evaluation salva atualiza o arquivo result.pkl a cada execução.

# %%
runner.run(save_each_evaluation=True)
# Out:
# /home/victor/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
runner.results
# Out:
#           df_name              model_name  \
# 0   bases/df3.csv  DecisionTreeClassifier
# 1   bases/df3.csv    KNeighborsClassifier
# 2   bases/df3.csv           MLPClassifier
# 3   bases/df3.csv              GaussianNB
# 4   bases/df3.csv               LinearSVC
# 5   bases/df3.csv      AdaBoostClassifier
# 6   bases/df3.csv  RandomForestClassifier
# 7   bases/df3.csv       BaggingClassifier
# 8   bases/df0.csv  DecisionTreeClassifier
# 9   bases/df0.csv    KNeighborsClassifier
# 10  bases/df0.csv           MLPClassifier
# 11  bases/df0.csv              GaussianNB
# 12  bases/df0.csv               LinearSVC
# 13  bases/df0.csv      AdaBoostClassifier
# 14  bases/df0.csv  RandomForestClassifier
# 15  bases/df0.csv       BaggingClassifier
# 16  bases/df1.csv  DecisionTreeClassifier
# 17  bases/df1.csv    KNeighborsClassifier
# 18  bases/df1.csv           MLPClassifier
# 19  bases/df1.csv              GaussianNB
# 20  bases/df1.csv               LinearSVC
# 21  bases/df1.csv      AdaBoostClassifier
# 22  bases/df1.csv  RandomForestClassifier
# 23  bases/df1.csv       BaggingClassifier
# 24  bases/df2.csv  DecisionTreeClassifier
# 25  bases/df2.csv    KNeighborsClassifier
# 26  bases/df2.csv           MLPClassifier
# 27  bases/df2.csv              GaussianNB
# 28  bases/df2.csv               LinearSVC
# 29  bases/df2.csv      AdaBoostClassifier
# 30  bases/df2.csv  RandomForestClassifier
# 31  bases/df2.csv       BaggingClassifier
# 32  bases/df4.csv  DecisionTreeClassifier
# 33  bases/df4.csv    KNeighborsClassifier
# 34  bases/df4.csv           MLPClassifier
# 35  bases/df4.csv              GaussianNB
# 36  bases/df4.csv               LinearSVC
# 37  bases/df4.csv      AdaBoostClassifier
# 38  bases/df4.csv  RandomForestClassifier
# 39  bases/df4.csv       BaggingClassifier
#
#                                          model_params split_type  split_value  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 1   {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 2   {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 3            {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 4   {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 5   {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 7   {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 8   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 10  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 11           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 12  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 13  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 15  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 16  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 17  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 18  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 19           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 20  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 21  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 22  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 23  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 25  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 26  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 27           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 28  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 29  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 30  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 31  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 33  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 34  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 35           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 36  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 37  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 38  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 39  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
#
#     model_seed  split_seed                        confusion_matrix  \
# 0         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 1          NaN          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 2         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 3          NaN          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 4         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 5         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 6         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 7         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 8         42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 9          NaN          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 10        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 11         NaN          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 12        42.0          42   [[101, 1, 0], [0, 99, 1], [0, 0, 98]]
# 13        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 14        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 15        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 16        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 17         NaN          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 18        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 19         NaN          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 20        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 21        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 22        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 23        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 24        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 25         NaN          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 26        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 27         NaN          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 28        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 29        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 30        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 31        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 32        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 33         NaN          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 34        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 35         NaN          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 36        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 37        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 38        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 39        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
#
#     accuracy_score  f1_score
# 0         1.000000  1.000000
# 1         1.000000  1.000000
# 2         1.000000  1.000000
# 3         1.000000  1.000000
# 4         1.000000  1.000000
# 5         1.000000  1.000000
# 6         1.000000  1.000000
# 7         1.000000  1.000000
# 8         1.000000  1.000000
# 9         1.000000  1.000000
# 10        1.000000  1.000000
# 11        1.000000  1.000000
# 12        0.993333  0.993333
# 13        1.000000  1.000000
# 14        1.000000  1.000000
# 15        1.000000  1.000000
# 16        1.000000  1.000000
# 17        1.000000  1.000000
# 18        1.000000  1.000000
# 19        1.000000  1.000000
# 20        1.000000  1.000000
# 21        1.000000  1.000000
# 22        1.000000  1.000000
# 23        1.000000  1.000000
# 24        1.000000  1.000000
# 25        1.000000  1.000000
# 26        1.000000  1.000000
# 27        1.000000  1.000000
# 28        1.000000  1.000000
# 29        1.000000  1.000000
# 30        1.000000  1.000000
# 31        1.000000  1.000000
# 32        1.000000  1.000000
# 33        1.000000  1.000000
# 34        1.000000  1.000000
# 35        1.000000  1.000000
# 36        1.000000  1.000000
# 37        1.000000  1.000000
# 38        1.000000  1.000000
# 39        1.000000  1.000000

# %%
pd.read_pickle("result.pkl")
# Out:
#           df_name              model_name  \
# 0   bases/df3.csv  DecisionTreeClassifier
# 1   bases/df3.csv    KNeighborsClassifier
# 2   bases/df3.csv           MLPClassifier
# 3   bases/df3.csv              GaussianNB
# 4   bases/df3.csv               LinearSVC
# 5   bases/df3.csv      AdaBoostClassifier
# 6   bases/df3.csv  RandomForestClassifier
# 7   bases/df3.csv       BaggingClassifier
# 8   bases/df0.csv  DecisionTreeClassifier
# 9   bases/df0.csv    KNeighborsClassifier
# 10  bases/df0.csv           MLPClassifier
# 11  bases/df0.csv              GaussianNB
# 12  bases/df0.csv               LinearSVC
# 13  bases/df0.csv      AdaBoostClassifier
# 14  bases/df0.csv  RandomForestClassifier
# 15  bases/df0.csv       BaggingClassifier
# 16  bases/df1.csv  DecisionTreeClassifier
# 17  bases/df1.csv    KNeighborsClassifier
# 18  bases/df1.csv           MLPClassifier
# 19  bases/df1.csv              GaussianNB
# 20  bases/df1.csv               LinearSVC
# 21  bases/df1.csv      AdaBoostClassifier
# 22  bases/df1.csv  RandomForestClassifier
# 23  bases/df1.csv       BaggingClassifier
# 24  bases/df2.csv  DecisionTreeClassifier
# 25  bases/df2.csv    KNeighborsClassifier
# 26  bases/df2.csv           MLPClassifier
# 27  bases/df2.csv              GaussianNB
# 28  bases/df2.csv               LinearSVC
# 29  bases/df2.csv      AdaBoostClassifier
# 30  bases/df2.csv  RandomForestClassifier
# 31  bases/df2.csv       BaggingClassifier
# 32  bases/df4.csv  DecisionTreeClassifier
# 33  bases/df4.csv    KNeighborsClassifier
# 34  bases/df4.csv           MLPClassifier
# 35  bases/df4.csv              GaussianNB
# 36  bases/df4.csv               LinearSVC
# 37  bases/df4.csv      AdaBoostClassifier
# 38  bases/df4.csv  RandomForestClassifier
# 39  bases/df4.csv       BaggingClassifier
#
#                                          model_params split_type  split_value  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 1   {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 2   {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 3            {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 4   {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 5   {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 7   {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 8   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 9   {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 10  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 11           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 12  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 13  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 15  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 16  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 17  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 18  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 19           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 20  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 21  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 22  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 23  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 25  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 26  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 27           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 28  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 29  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 30  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 31  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...    holdout          0.3
# 33  {'algorithm': 'auto', 'leaf_size': 30, 'metric...    holdout          0.3
# 34  {'activation': 'relu', 'alpha': 0.0001, 'batch...    holdout          0.3
# 35           {'priors': None, 'var_smoothing': 1e-09}    holdout          0.3
# 36  {'C': 1.0, 'class_weight': None, 'dual': True,...    holdout          0.3
# 37  {'algorithm': 'SAMME.R', 'base_estimator': 'de...    holdout          0.3
# 38  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...    holdout          0.3
# 39  {'base_estimator': 'deprecated', 'bootstrap': ...    holdout          0.3
#
#     model_seed  split_seed                        confusion_matrix  \
# 0         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 1          NaN          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 2         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 3          NaN          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 4         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 5         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 6         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 7         42.0          42   [[99, 0, 0], [0, 94, 0], [0, 0, 107]]
# 8         42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 9          NaN          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 10        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 11         NaN          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 12        42.0          42   [[101, 1, 0], [0, 99, 1], [0, 0, 98]]
# 13        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 14        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 15        42.0          42  [[101, 0, 0], [0, 100, 0], [0, 0, 99]]
# 16        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 17         NaN          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 18        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 19         NaN          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 20        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 21        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 22        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 23        42.0          42  [[105, 0, 0], [0, 109, 0], [0, 0, 86]]
# 24        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 25         NaN          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 26        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 27         NaN          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 28        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 29        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 30        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 31        42.0          42   [[95, 0, 0], [0, 109, 0], [0, 0, 96]]
# 32        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 33         NaN          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 34        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 35         NaN          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 36        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 37        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 38        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
# 39        42.0          42   [[110, 0, 0], [0, 95, 0], [0, 0, 95]]
#
#     accuracy_score  f1_score
# 0         1.000000  1.000000
# 1         1.000000  1.000000
# 2         1.000000  1.000000
# 3         1.000000  1.000000
# 4         1.000000  1.000000
# 5         1.000000  1.000000
# 6         1.000000  1.000000
# 7         1.000000  1.000000
# 8         1.000000  1.000000
# 9         1.000000  1.000000
# 10        1.000000  1.000000
# 11        1.000000  1.000000
# 12        0.993333  0.993333
# 13        1.000000  1.000000
# 14        1.000000  1.000000
# 15        1.000000  1.000000
# 16        1.000000  1.000000
# 17        1.000000  1.000000
# 18        1.000000  1.000000
# 19        1.000000  1.000000
# 20        1.000000  1.000000
# 21        1.000000  1.000000
# 22        1.000000  1.000000
# 23        1.000000  1.000000
# 24        1.000000  1.000000
# 25        1.000000  1.000000
# 26        1.000000  1.000000
# 27        1.000000  1.000000
# 28        1.000000  1.000000
# 29        1.000000  1.000000
# 30        1.000000  1.000000
# 31        1.000000  1.000000
# 32        1.000000  1.000000
# 33        1.000000  1.000000
# 34        1.000000  1.000000
# 35        1.000000  1.000000
# 36        1.000000  1.000000
# 37        1.000000  1.000000
# 38        1.000000  1.000000
# 39        1.000000  1.000000
